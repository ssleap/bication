# %%
import pandas as pd

# %%
df = pd.read_csv('day.csv', encoding = 'utf-8')

# %%
df
# Out:
#               '대여일자' '대여소번호'                '대여소' '대여구분코드' 'SEX_CD' '연령대코드'  \
# 0       '2018-06-01'   '733'       ' 신정이펜하우스314동'     '정기'      'F'  '~10대'
# 1       '2018-06-01'   '736'             ' 오솔길공원'     '정기'      'F'  '~10대'
# 2       '2018-06-01'   '746'          ' 목동2단지 상가'     '정기'      'F'  '~10대'
# 3       '2018-06-01'   '945'           ' 기자촌 사거리'     '정기'      'F'  '~10대'
# 4       '2018-06-01'   '508'        ' 성수아카데미타워 앞'     '정기'      'F'  '~10대'
# 5       '2018-06-01'  '1041'            ' 묘곡초등학교'     '정기'      'F'  '~10대'
# 6       '2018-06-01'  '1044'             ' 굽은다리역'     '정기'      'F'  '~10대'
# 7       '2018-06-01'  '1152'            ' 마곡역교차로'     '정기'      'F'  '~10대'
# 8       '2018-06-01'  '1153'          ' 발산역 2번출구'     '정기'      'F'  '~10대'
# 9       '2018-06-01'  '1157'              ' 강서구청'     '정기'      'F'  '~10대'
# 10      '2018-06-01'  '1251'          ' 석촌역 2번출구'     '정기'      'F'  '~10대'
# ...

# %%
import datetime
import calendar

# %%
datetime.datetime.weekday(datetime.date(2018, 6, 1))
# Out:
# 4

# %%
datetime.date(2018, 6, 1)
# Out:
# datetime.date(2018, 6, 1)

# %%
df['week'] = df.iloc[:,0].map(lambda x : datetime.datetime.weekday(datetime.date(int(x.split('-')[0]),int(x.split('-')[1]),int(x.split('-')[2]))))

# %%
int('01')
# Out:
# 1

# %%
type("대여일자")
# Out:
# str

# %%
type(df.iloc[:, 1])
# Out:
# pandas.core.series.Series

# %%
df["'대여일자'"]
# Out:
# 0         '2018-06-01'
# 1         '2018-06-01'
# 2         '2018-06-01'
# 3         '2018-06-01'
# 4         '2018-06-01'
# 5         '2018-06-01'
# 6         '2018-06-01'
# 7         '2018-06-01'
# 8         '2018-06-01'
# 9         '2018-06-01'
# 10        '2018-06-01'
# 11        '2018-06-01'
# 12        '2018-06-01'
# 13        '2018-06-01'
# 14        '2018-06-01'
# 15        '2018-06-01'
# 16        '2018-06-01'
# 17        '2018-06-01'
# 18        '2018-06-01'
# 19        '2018-06-01'
# 20        '2018-06-01'
# 21        '2018-06-01'
# 22        '2018-06-01'
# 23        '2018-06-01'
# 24        '2018-06-01'
# 25        '2018-06-01'
# 26        '2018-06-01'
# 27        '2018-06-01'
# 28        '2018-06-01'
# 29        '2018-06-01'
#               ...
# 378575    '2018-06-30'
# 378576    '2018-06-30'
# 378577    '2018-06-30'
# 378578    '2018-06-30'
# 378579    '2018-06-30'
# 378580    '2018-06-30'
# 378581    '2018-06-30'
# 378582    '2018-06-30'
# 378583    '2018-06-30'
# ...

# %%
df.iloc[:,1] = df.iloc[:,1].str.replace("'","")

# %%
df
# Out:
#             '대여일자' '대여소번호'                '대여소' '대여구분코드' 'SEX_CD' '연령대코드'  \
# 0       2018-06-01     733       ' 신정이펜하우스314동'     '정기'      'F'  '~10대'
# 1       2018-06-01     736             ' 오솔길공원'     '정기'      'F'  '~10대'
# 2       2018-06-01     746          ' 목동2단지 상가'     '정기'      'F'  '~10대'
# 3       2018-06-01     945           ' 기자촌 사거리'     '정기'      'F'  '~10대'
# 4       2018-06-01     508        ' 성수아카데미타워 앞'     '정기'      'F'  '~10대'
# 5       2018-06-01    1041            ' 묘곡초등학교'     '정기'      'F'  '~10대'
# 6       2018-06-01    1044             ' 굽은다리역'     '정기'      'F'  '~10대'
# 7       2018-06-01    1152            ' 마곡역교차로'     '정기'      'F'  '~10대'
# 8       2018-06-01    1153          ' 발산역 2번출구'     '정기'      'F'  '~10대'
# 9       2018-06-01    1157              ' 강서구청'     '정기'      'F'  '~10대'
# 10      2018-06-01    1251          ' 석촌역 2번출구'     '정기'      'F'  '~10대'
# 11      2018-06-01    1262        ' 송파여성문화회관 앞'     '정기'      'F'  '~10대'
# ...

# %%
df
# Out:
#             '대여일자' '대여소번호'                '대여소' '대여구분코드' 'SEX_CD' '연령대코드'  \
# 0       2018-06-01   '733'       ' 신정이펜하우스314동'     '정기'      'F'  '~10대'
# 1       2018-06-01   '736'             ' 오솔길공원'     '정기'      'F'  '~10대'
# 2       2018-06-01   '746'          ' 목동2단지 상가'     '정기'      'F'  '~10대'
# 3       2018-06-01   '945'           ' 기자촌 사거리'     '정기'      'F'  '~10대'
# 4       2018-06-01   '508'        ' 성수아카데미타워 앞'     '정기'      'F'  '~10대'
# 5       2018-06-01  '1041'            ' 묘곡초등학교'     '정기'      'F'  '~10대'
# 6       2018-06-01  '1044'             ' 굽은다리역'     '정기'      'F'  '~10대'
# 7       2018-06-01  '1152'            ' 마곡역교차로'     '정기'      'F'  '~10대'
# 8       2018-06-01  '1153'          ' 발산역 2번출구'     '정기'      'F'  '~10대'
# 9       2018-06-01  '1157'              ' 강서구청'     '정기'      'F'  '~10대'
# 10      2018-06-01  '1251'          ' 석촌역 2번출구'     '정기'      'F'  '~10대'
# 11      2018-06-01  '1262'        ' 송파여성문화회관 앞'     '정기'      'F'  '~10대'
# ...
