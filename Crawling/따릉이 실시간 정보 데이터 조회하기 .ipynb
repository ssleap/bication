# %%
import json

# %%
from pymongo import MongoClient
# client = MongoClient( host="175.119.200.201",
#                                 port=27017,
#                                 username="paul0115",
#                                 password="paul0115",
#                                 authSource="admin",
#                                 authMechanism="SCRAM-SHA-256")

username="paul0115"
password="paul0115"
client = MongoClient('mongodb://%s:%s@175.119.200.201/default_db?authSource=admin' % (username, password))

print(client.HOST)
print(client.server_info())
# Out:
# localhost
# ...

# %%
client.database_names()
# Out:
# /home/paul/.virtualenvs/car/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   """Entry point for launching an IPython kernel.
# ['admin', 'config', 'ddarungDB', 'local']

# %%
ddarungDB = client.get_database("ddarungDB")

# %%
ddarungDB.collection_names()
# Out:
# /home/paul/.virtualenvs/car/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['realtimeStatoinStatus']

# %%
print(client.ddarungDB.realtimeStatoinStatus.count())
# Out:
# 22025
# /home/paul/.virtualenvs/car/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.

# %%
from pprint import pprint
pprint(client.ddarungDB.realtimeStatoinStatus.find({})[20000])
# Out:
# {'_id': ObjectId('5b7c6cbdf55c8929efa1e189'),
#  'checkResult': True,
#  'dateTimeTag': datetime.datetime(2018, 8, 22, 4, 49, 17, 698000),
#  'holiday': False,
#  'loginYn': 'N',
#  'realtimeList': [{'bikeTotCnt': None,
#                    'bkmkSeq': None,
#                    'brokenApFlg': None,
#                    'brokenArmFlg': None,
#                    'brokenBikeFlg': None,
#                    'closeFlg': None,
#                    'criticalFlg': None,
#                    'currentPageNo': 1,
#                    'currnetStatus': None,
#                    'firstRecordIndex': 0,
#                    'lang': 'LAG_001',
#                    'locateNo': None,
#                    'mode': None,
#                    'pageSize': 0,
#                    'pageYn': 'Y',
#                    'parkingBike': None,
#                    'parkingBikeTotCnt': '1',
#                    'parkingRack': None,
#                    'parkingRackTotCnt': None,
# ...
